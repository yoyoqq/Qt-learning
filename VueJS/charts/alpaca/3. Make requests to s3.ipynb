# %%
from datetime import datetime, timezone

# %%
import boto3

s3 = boto3.client(
    "s3", 
    endpoint_url = "http://localhost:9100",
    aws_access_key_id = "minioadmin",
    aws_secret_access_key = "minioadmin", 
    region_name = "us-east-1",
)

# %%
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '188A0DC42E8F6EA0',
#   'HostId': '40fd399614142fea3be9690e18526c1881df2b9fc838b215f9c270b056695f9e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '369',
#    'content-type': 'application/xml',
#    'server': 'MinIO AIStor',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': '40fd399614142fea3be9690e18526c1881df2b9fc838b215f9c270b056695f9e',
#    'x-amz-request-id': '188A0DC42E8F6EA0',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '624',
#    'x-ratelimit-remaining': '624',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Mon, 12 Jan 2026 18:02:19 GMT'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'market-data',
#    'CreationDate': datetime.datetime(2026, 1, 10, 16, 18, 43, 288000, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'minio',
#   'ID': '02d6176db174dc93cb1b899f7c6078f08654445fe8cf1b6ce98d8855f66bdbf4'}}

# %%
s3.list_objects_v2(
    Bucket="market-data",
    Prefix="symbol=SPY/year=2020/"
)
# Out:
# {'ResponseMetadata': {'RequestId': '188A0DC64E4D98B4',
#   'HostId': '40fd399614142fea3be9690e18526c1881df2b9fc838b215f9c270b056695f9e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '3168',
#    'content-type': 'application/xml',
#    'server': 'MinIO AIStor',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': '40fd399614142fea3be9690e18526c1881df2b9fc838b215f9c270b056695f9e',
#    'x-amz-request-id': '188A0DC64E4D98B4',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '624',
#    'x-ratelimit-remaining': '624',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Mon, 12 Jan 2026 18:02:29 GMT'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Contents': [{'Key': 'symbol=SPY/year=2020/month=01.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 108000, tzinfo=tzutc()),
#    'ETag': '"378e84d6e62f12118d4fb47da3b1108f"',
#    'Size': 441587,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=02.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 136000, tzinfo=tzutc()),
#    'ETag': '"8629eae1cbe43f46fd8b482777552870"',
#    'Size': 419929,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=03.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 168000, tzinfo=tzutc()),
#    'ETag': '"986d714adbd81ccb5c7d1d3676eac8a7"',
#    'Size': 617833,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=04.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 203000, tzinfo=tzutc()),
#    'ETag': '"bba8993ce8196ffd5f9c8da798f3bb0e"',
#    'Size': 557238,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=05.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 234000, tzinfo=tzutc()),
#    'ETag': '"2ef201f339bbdeaeecdec1cd26be9093"',
#    'Size': 428633,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=06.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 268000, tzinfo=tzutc()),
#    'ETag': '"00a94b7e62944fef683432c37f39e940"',
#    'Size': 552147,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=07.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 303000, tzinfo=tzutc()),
#    'ETag': '"5aaf2327e58d793d3939904be28225d0"',
#    'Size': 506348,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=08.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 329000, tzinfo=tzutc()),
#    'ETag': '"c955f1a48628ed33492b8c3b8251824a"',
#    'Size': 457724,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=09.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 356000, tzinfo=tzutc()),
#    'ETag': '"b1c7e5fa819017cb013993b8f924806d"',
#    'Size': 505201,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=10.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 384000, tzinfo=tzutc()),
#    'ETag': '"4a6993bd2625fd575807906e75fe728e"',
#    'Size': 520129,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=11.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 412000, tzinfo=tzutc()),
#    'ETag': '"07a96bde0e642af8174c406c88b53c01"',
#    'Size': 480111,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'symbol=SPY/year=2020/month=12.parquet',
#    'LastModified': datetime.datetime(2026, 1, 10, 16, 48, 27, 436000, tzinfo=tzutc()),
#    'ETag': '"8c980ec0d496efc12b8fe9545a2a8343"',
#    'Size': 470092,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'market-data',
#  'Prefix': 'symbol=SPY/year=2020/',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 12}

# %%
obj = s3.get_object(
    Bucket="market-data",
    Key="symbol=SPY/year=2020/month=01.parquet"
)
data = obj["Body"].read()

# %%
import polars as pl

path = f"s3://market-data/symbol=SPY/**/*.parquet",
df = pl.scan_parquet(
    path,
    storage_options={
        "aws_access_key_id": "minioadmin",
        "aws_secret_access_key": "minioadmin",
        "endpoint_url": "http://localhost:9100",
    },
)

print(df.select(pl.len()).collect())
# Out:
# shape: (1, 1)
# ┌─────────┐
# │ len     │
# │ ---     │
# │ u32     │
# ╞═════════╡
# │ 1238488 │
# └─────────┘

# %% [markdown]
# # Get within a range

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import polars as pl

def month_range(start, end):
    cur = start.replace(day=1)
    while cur <= end:
        yield cur
        cur += relativedelta(months=1)


def load_ticks(symbol, start_ts, end_ts):
    paths = []

    for d in month_range(start_ts, end_ts):
        paths.append(
            f"s3://market-data/symbol={symbol}/year={d.year}/month={d.month:02d}.parquet"
        )

    df = pl.scan_parquet(
        paths,
        storage_options={
            "aws_access_key_id": "minioadmin",
            "aws_secret_access_key": "minioadmin",
            "endpoint_url": "http://localhost:9100",
        },
    )

    df = df.filter(
        (pl.col("timestamp") >= start_ts) &
        (pl.col("timestamp") <= end_ts)
    ).sort("timestamp")

    return df.collect()

# %%
print(    datetime(2020, 1, 2, 0, 0, tzinfo=timezone.utc))
# Out:
# 2020-01-02 00:00:00+00:00

# %%
ticks = load_ticks(
    "SPY",
    datetime(2020, 1, 2, 0, 0, tzinfo=timezone.utc),
    datetime(2023, 1, 3, 0, 0, tzinfo=timezone.utc),
)

print(ticks.shape)
print(ticks.head())
# Out:
# (628944, 9)
# shape: (5, 9)
# ┌────────┬──────────────────────┬────────┬────────┬───┬────────┬────────┬─────────────┬────────────┐
# │ symbol ┆ timestamp            ┆ open   ┆ high   ┆ … ┆ close  ┆ volume ┆ trade_count ┆ vwap       │
# │ ---    ┆ ---                  ┆ ---    ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---         ┆ ---        │
# │ str    ┆ datetime[ns, UTC]    ┆ f64    ┆ f64    ┆   ┆ f64    ┆ f64    ┆ f64         ┆ f64        │
# ╞════════╪══════════════════════╪════════╪════════╪═══╪════════╪════════╪═════════════╪════════════╡
# │ SPY    ┆ 2020-01-02 09:00:00  ┆ 323.52 ┆ 323.67 ┆ … ┆ 323.56 ┆ 9391.0 ┆ 18.0        ┆ 323.575879 │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:01:00  ┆ 323.68 ┆ 323.69 ┆ … ┆ 323.61 ┆ 905.0  ┆ 6.0         ┆ 323.651111 │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:02:00  ┆ 323.68 ┆ 323.68 ┆ … ┆ 323.68 ┆ 121.0  ┆ 1.0         ┆ 323.68     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:03:00  ┆ 323.69 ┆ 323.69 ┆ … ┆ 323.69 ┆ 127.0  ┆ 3.0         ┆ 323.69     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:04:00  ┆ 323.64 ┆ 323.64 ┆ … ┆ 323.64 ┆ 100.0  ┆ 1.0         ┆ 323.64     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# └────────┴──────────────────────┴────────┴────────┴───┴────────┴────────┴─────────────┴────────────┘

# %%
ticks
# Out:
# shape: (628_944, 9)
# ┌────────┬──────────────────────┬────────┬────────┬───┬────────┬────────┬─────────────┬────────────┐
# │ symbol ┆ timestamp            ┆ open   ┆ high   ┆ … ┆ close  ┆ volume ┆ trade_count ┆ vwap       │
# │ ---    ┆ ---                  ┆ ---    ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---         ┆ ---        │
# │ str    ┆ datetime[ns, UTC]    ┆ f64    ┆ f64    ┆   ┆ f64    ┆ f64    ┆ f64         ┆ f64        │
# ╞════════╪══════════════════════╪════════╪════════╪═══╪════════╪════════╪═════════════╪════════════╡
# │ SPY    ┆ 2020-01-02 09:00:00  ┆ 323.52 ┆ 323.67 ┆ … ┆ 323.56 ┆ 9391.0 ┆ 18.0        ┆ 323.575879 │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:01:00  ┆ 323.68 ┆ 323.69 ┆ … ┆ 323.61 ┆ 905.0  ┆ 6.0         ┆ 323.651111 │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:02:00  ┆ 323.68 ┆ 323.68 ┆ … ┆ 323.68 ┆ 121.0  ┆ 1.0         ┆ 323.68     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:03:00  ┆ 323.69 ┆ 323.69 ┆ … ┆ 323.69 ┆ 127.0  ┆ 3.0         ┆ 323.69     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2020-01-02 09:04:00  ┆ 323.64 ┆ 323.64 ┆ … ┆ 323.64 ┆ 100.0  ┆ 1.0         ┆ 323.64     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ …      ┆ …                    ┆ …      ┆ …      ┆ … ┆ …      ┆ …      ┆ …           ┆ …          │
# │ SPY    ┆ 2022-12-30 22:54:00  ┆ 383.1  ┆ 383.1  ┆ … ┆ 383.1  ┆ 1670.0 ┆ 17.0        ┆ 383.099333 │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2022-12-30 22:56:00  ┆ 383.1  ┆ 383.1  ┆ … ┆ 383.1  ┆ 807.0  ┆ 21.0        ┆ 383.1      │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2022-12-30 22:58:00  ┆ 383.11 ┆ 383.11 ┆ … ┆ 383.11 ┆ 538.0  ┆ 5.0         ┆ 383.11     │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2022-12-30 22:59:00  ┆ 383.1  ┆ 383.1  ┆ … ┆ 383.1  ┆ 505.0  ┆ 6.0         ┆ 383.1      │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# │ SPY    ┆ 2022-12-30 23:00:00  ┆ 383.1  ┆ 383.1  ┆ … ┆ 383.1  ┆ 383.0  ┆ 17.0        ┆ 383.1      │
# │        ┆ UTC                  ┆        ┆        ┆   ┆        ┆        ┆             ┆            │
# └────────┴──────────────────────┴────────┴────────┴───┴────────┴────────┴─────────────┴────────────┘

# %%
import polars as pl

def resample_bars(bars: pl.DataFrame, timeframe: str) -> pl.DataFrame:
    """
    timeframe: "5m", "15m", "1h", "1d", "1w", "1mo"
    """

    if timeframe in {"5m", "15m", "1h"}:
        rule = {"5m": "5m", "15m": "15m", "1h": "1h"}[timeframe]
        df = bars.with_columns(pl.col("timestamp").dt.truncate(rule).alias("bar"))

    elif timeframe == "1d":
        df = bars.with_columns(pl.col("timestamp").dt.date().alias("bar"))

    elif timeframe == "1w":
        df = bars.with_columns(pl.col("timestamp").dt.truncate("1w").alias("bar"))

    elif timeframe == "1mo":
        df = bars.with_columns(
            pl.col("timestamp")
            .dt.strftime("%Y-%m-01")
            .str.strptime(pl.Date)
            .alias("bar")
        )

    else:
        raise ValueError("timeframe must be one of: 5m, 15m, 1h, 1d, 1w, 1mo")

    out = (
        df.group_by("bar")
        .agg([
            pl.col("open").first().alias("open"),
            pl.col("high").max().alias("high"),
            pl.col("low").min().alias("low"),
            pl.col("close").last().alias("close"),
            pl.col("volume").sum().alias("volume"),
            pl.col("trade_count").sum().alias("trade_count"),
            ((pl.col("vwap") * pl.col("volume")).sum() / pl.col("volume").sum()).alias("vwap"),
        ])
        .sort("bar")
    )

    return out

# %%
bars_5m  = resample_bars(ticks, "5m")
bars_15m = resample_bars(ticks, "15m")
bars_1h  = resample_bars(ticks, "1h")
bars_1d  = resample_bars(ticks, "1d")

print(bars_5m.head())
# Out:
# shape: (5, 8)
# ┌─────────────────────────┬────────┬────────┬────────┬────────┬─────────┬─────────────┬────────────┐
# │ bar                     ┆ open   ┆ high   ┆ low    ┆ close  ┆ volume  ┆ trade_count ┆ vwap       │
# │ ---                     ┆ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---     ┆ ---         ┆ ---        │
# │ datetime[ns, UTC]       ┆ f64    ┆ f64    ┆ f64    ┆ f64    ┆ f64     ┆ f64         ┆ f64        │
# ╞═════════════════════════╪════════╪════════╪════════╪════════╪═════════╪═════════════╪════════════╡
# │ 2020-01-02 09:00:00 UTC ┆ 323.52 ┆ 323.69 ┆ 323.52 ┆ 323.64 ┆ 10644.0 ┆ 29.0        ┆ 323.585423 │
# │ 2020-01-02 09:05:00 UTC ┆ 323.71 ┆ 323.78 ┆ 323.7  ┆ 323.76 ┆ 3333.0  ┆ 11.0        ┆ 323.720596 │
# │ 2020-01-02 09:10:00 UTC ┆ 323.76 ┆ 323.83 ┆ 323.73 ┆ 323.81 ┆ 3900.0  ┆ 13.0        ┆ 323.814102 │
# │ 2020-01-02 09:15:00 UTC ┆ 323.76 ┆ 323.76 ┆ 323.76 ┆ 323.76 ┆ 100.0   ┆ 1.0         ┆ 323.76     │
# │ 2020-01-02 09:20:00 UTC ┆ 323.76 ┆ 323.76 ┆ 323.76 ┆ 323.76 ┆ 100.0   ┆ 1.0         ┆ 323.76     │
# └─────────────────────────┴────────┴────────┴────────┴────────┴─────────┴─────────────┴────────────┘
